# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
path = r"C:\Users\godsw\Desktop\Study\Data Science\IBM\Data Analysis with Python\Final Assignment- Predict House Prices\kc_house_data_NaN.csv"

# %%
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %% [markdown]
# Data Wrangling

# %%
#dropping columns Unnamed:0 and id
df.drop(["Unnamed: 0","id"], axis = 1, inplace = True)

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
#print the number of NaN values in columns bedrooms and bathrooms
print("Number of NaN values in column 'bedrooms' is:", df['bedrooms'].isnull().sum())
print("Number of NaN values in column 'bathrooms' is:",df['bathrooms'].isnull().sum())
# Out:
# Number of NaN values in column 'bedrooms' is: 13
# Number of NaN values in column 'bathrooms' is: 10

# %%
mean = df['bedrooms'].mean()
df['bedrooms'].replace(np.nan, mean,inplace = True )

# %%
mean = df['bathrooms'].mean()
df['bathrooms'].replace(np.nan, mean,inplace = True )

# %%
print("Number of NaN values in column 'bedrooms' is:", df['bedrooms'].isnull().sum())
print("Number of NaN values in column 'bathrooms' is:",df['bathrooms'].isnull().sum())
# Out:
# Number of NaN values in column 'bedrooms' is: 0
# Number of NaN values in column 'bathrooms' is: 0

# %% [markdown]
# Exploratory Data Analysis

# %%
#count houses with unique floor values
df_unique_floors = df['floors'].value_counts()
df_unique_floors.to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
#Using boxplots to determine if houses with or without waterfront have more outliers
sns.boxplot(x='waterfront',y='price', data = df)
print('Houses without a waterfront appear to have more price outliers')
# Out:
# Houses without a waterfront appear to have more price outliers

# %%
#to determine if the feature sqft_above is negatively or positively correlated with price
sns.regplot(x='sqft_above', y='price', data = df)
print('A positive correlation appears between sqft_above and price')
# Out:
# A positive correlation appears between sqft_above and price

# %%
#using corr() to show how each feature correlates with price
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
#Let's plot sqft_living against price
sns.regplot(x='sqft_living',y='price',data = df)

# %% [markdown]
# Model Development

# %%
#Fitting a linear regression model to predict the 'price' using the feature 'sqft_living' and calculating R^2
X1 = df[['sqft_living']]
Y1 = df[['price']]
lm1 = LinearRegression()
lm1.fit(X1,Y1)
lm1.score(X1,Y1)
# Out:
# 0.49285321790379316

# %%
#Fit a linear regression model to predict the 'price' using the list of features and calulate R^2
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]
X2 = df[features]
Y2 = df[['price']]
lm2 = LinearRegression()
lm2.fit(X2,Y2)
lm2.score(X2,Y2)
# Out:
# 0.6576951666037494

# %%
#Use the list to create a pipeline object to predict the 'price', fit the object using the features in the list features, and calculate the R^2.
#ypipe is predicted price
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]
pipe = Pipeline(Input)
pipe.fit(X2,Y2)
ypipe = pipe.predict(X2)
ypipe[0:10]
pipe.score(X2,Y2)
# Out:
# 0.7513404614351351

# %%
ypipe[0:10]
# Out:
# array([[ 349643.25],
#        [ 559093.25],
#        [ 449229.25],
#        [ 393313.25],
#        [ 521763.25],
#        [2035293.25],
#        [ 210365.25],
#        [ 291325.25],
#        [ 442497.25],
#        [ 290683.75]])
